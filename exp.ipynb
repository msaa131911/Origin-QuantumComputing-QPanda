# %% [markdown]
# <a href="https://colab.research.google.com/github/msaa131911/Origin-QuantumComputing-QPanda/blob/main/exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyqpanda3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.7/31.7 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 52.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.7/531.7 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from pyqpanda3.core import QCircuit, QProg, H, CNOT, measure, CPUQVM

circuit = QCircuit(2)
circuit << H(0)
circuit << CNOT(0, 1)

prog = QProg()
prog << circuit
prog << measure(0, 0) << measure(1, 1)

machine = CPUQVM()
machine.run(prog, 1000)
print(machine.result().get_counts())
# Out:
# {'11': 513, '00': 487}
